# %%
import sys
from pathlib import Path

script_dir = Path.cwd()
sys.path.insert(0, str(script_dir.parent.parent))

from visualization import plot_dataset_comparison

# %matplotlib inline

dataset_names = ['Pitt', 'ADReSS', 'Lu']
accuracies = [61.62, 65.62, 93.75]

plot_dataset_comparison(
    dataset_names=dataset_names,
    accuracies=accuracies,
    title='eGeMaps Train and Test in Same Datasets',
    figsize=(max(8, len(dataset_names)*2), 5)
)
